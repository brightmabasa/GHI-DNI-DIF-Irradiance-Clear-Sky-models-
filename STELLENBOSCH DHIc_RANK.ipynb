# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# Load the data from the CSV file
df = pd.read_csv('STEL_DHIc_metrics_results.csv')

# Handle NaN, infinity, or large values in the dataset
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)


#import io
# Read the data into a pandas DataFrame
#df = pd.read_csv(io.StringIO(data), sep='\t')

# %%
# Calculate the absolute value of MBE
df['|MBE|'] = df['MBE'].abs()

# Rank the data based on |MBE|, MAE, and RMSE
df['Rank_MBE'] = df['|MBE|'].rank()
df['Rank_MAE'] = df['MAE'].rank()
df['Rank_RMSE'] = df['RMSE'].rank()

# Calculate the mean rank for each row
df['Mean_Rank'] = df[['Rank_MBE', 'Rank_MAE', 'Rank_RMSE']].mean(axis=1)

# Sort the DataFrame by Mean_Rank
df_sorted = df.sort_values(by='Mean_Rank')

# Select relevant columns for display and include model name
df_sorted.insert(0, 'Model', df_sorted.index)

# Round off the results to 2 decimal digits
df_sorted = df_sorted.round(2)

# Add a numeric rank column based on Mean_Rank starting from 1
df_sorted['Numeric_Rank'] = df_sorted['Mean_Rank'].rank(method='min').astype(int)
df['Numeric_Rank']= df_sorted['Numeric_Rank']

# Save the results to a CSV file
#df_sorted.to_csv('ranking_results.csv', index=False)

# Display the DataFrame with model names and rankings
#print(df_sorted[['Model', '|MBE|', 'MAE', 'RMSE', 'Rank_MBE', 'Rank_MAE', 'Rank_RMSE', 'Mean_Rank', 'Numeric_Rank']])
df_sorted
# Out:
#     Model         Unnamed: 0    MBE   rMBE    RMSE   rRMSE    r2    MAE  \
# 1       1       Mabasa_DHIcs  -2.36  -2.98   30.52   38.54  0.18  18.53
# 6       6      Schulze_DHIcs  -3.28  -4.14   30.72   38.80  0.17  18.39
# 8       8       Bulger_DHIcs   7.36   9.30   31.28   39.50  0.14  22.17
# 13     13           TJ_DHIcs   4.29   5.42   31.59   39.90  0.13  21.36
# 0       0        dhi_McClear  16.78  21.18   31.46   39.73  0.13  24.34
# 9       9       Sharma_DHIcs  13.86  17.50   33.28   42.03  0.03  25.78
# 11     11          HLJ_DHIcs  15.53  19.62   34.15   43.12 -0.02  27.08
# 4       4     BigaRosa_DHIcs  22.17  28.00   37.79   47.73 -0.25  31.45
# 5       5  Brichambaut_DHIcs  25.75  32.52   39.88   50.36 -0.39  34.40
# 2       2           SS_DHIcs  28.02  35.38   41.25   52.09 -0.49  35.96
# 3       3           IP_DHIcs  34.04  42.98   46.88   59.20 -0.92  41.34
# 10     10   ElMghouchi_DHIcs -40.66 -51.35   51.42   64.94 -1.31  40.66
# 7       7          DPP_DHIcs  76.13  96.14   92.69  117.05 -6.51  78.90
# 12     12       FuRich_DHIcs  69.72  88.04  102.37  129.28 -8.17  79.84
#
#       rMAE  |MBE|  Rank_MBE  Rank_MAE  Rank_RMSE  Mean_Rank  Numeric_Rank
# 1    23.40   2.36       1.0       2.0        1.0       1.33             1
# 6    23.22   3.28       2.0       1.0        2.0       1.67             2
# 8    27.99   7.36       4.0       4.0        3.0       3.67             3
# 13   26.98   4.29       3.0       3.0        5.0       3.67             3
# 0    30.74  16.78       7.0       5.0        4.0       5.33             5
# 9    32.55  13.86       5.0       6.0        6.0       5.67             6
# 11   34.20  15.53       6.0       7.0        7.0       6.67             7
# 4    39.72  22.17       8.0       8.0        8.0       8.00             8
# 5    43.44  25.75       9.0       9.0        9.0       9.00             9
# 2    45.41  28.02      10.0      10.0       10.0      10.00            10
# 3    52.20  34.04      11.0      12.0       11.0      11.33            11
# 10   51.35  40.66      12.0      11.0       12.0      11.67            12
# 7    99.64  76.13      14.0      13.0       13.0      13.33            13
# 12  100.82  69.72      13.0      14.0       14.0      13.67            14
#     Model         Unnamed: 0    MBE   rMBE    RMSE   rRMSE    r2    MAE  \
# 1       1       Mabasa_DHIcs  -2.36  -2.98   30.52   38.54  0.18  18.53
# 6       6      Schulze_DHIcs  -3.28  -4.14   30.72   38.80  0.17  18.39
# 8       8       Bulger_DHIcs   7.36   9.30   31.28   39.50  0.14  22.17
# 13     13           TJ_DHIcs   4.29   5.42   31.59   39.90  0.13  21.36
# 0       0        dhi_McClear  16.78  21.18   31.46   39.73  0.13  24.34
# 9       9       Sharma_DHIcs  13.86  17.50   33.28   42.03  0.03  25.78
# 11     11          HLJ_DHIcs  15.53  19.62   34.15   43.12 -0.02  27.08
# 4       4     BigaRosa_DHIcs  22.17  28.00   37.79   47.73 -0.25  31.45
# 5       5  Brichambaut_DHIcs  25.75  32.52   39.88   50.36 -0.39  34.40
# 2       2           SS_DHIcs  28.02  35.38   41.25   52.09 -0.49  35.96
# 3       3           IP_DHIcs  34.04  42.98   46.88   59.20 -0.92  41.34
# 10     10   ElMghouchi_DHIcs -40.66 -51.35   51.42   64.94 -1.31  40.66
# 7       7          DPP_DHIcs  76.13  96.14   92.69  117.05 -6.51  78.90
# 12     12       FuRich_DHIcs  69.72  88.04  102.37  129.28 -8.17  79.84
#
#       rMAE  |MBE|  Rank_MBE  Rank_MAE  Rank_RMSE  Mean_Rank  Numeric_Rank
# 1    23.40   2.36       1.0       2.0        1.0       1.33             1
# 6    23.22   3.28       2.0       1.0        2.0       1.67             2
# 8    27.99   7.36       4.0       4.0        3.0       3.67             3
# 13   26.98   4.29       3.0       3.0        5.0       3.67             3
# 0    30.74  16.78       7.0       5.0        4.0       5.33             5
# 9    32.55  13.86       5.0       6.0        6.0       5.67             6
# 11   34.20  15.53       6.0       7.0        7.0       6.67             7
# 4    39.72  22.17       8.0       8.0        8.0       8.00             8
# 5    43.44  25.75       9.0       9.0        9.0       9.00             9
# 2    45.41  28.02      10.0      10.0       10.0      10.00            10
# 3    52.20  34.04      11.0      12.0       11.0      11.33            11
# 10   51.35  40.66      12.0      11.0       12.0      11.67            12
# 7    99.64  76.13      14.0      13.0       13.0      13.33            13
# 12  100.82  69.72      13.0      14.0       14.0      13.67            14

# %%
df = df.round(2)
df.to_csv('STEL_DHIc_FINAL_Ranking_Results.csv', index=False)
